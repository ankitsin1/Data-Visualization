# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints, linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints, linestyle='dashed', color='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,color='purple')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,color='purple',linestyle='dotted')
plt.xlabel('AVERAGE PULSE')
plt.ylabel('CALORIE BURNAGE',color='r')
plt.title('GRAPH',color='orange')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,color='purple',linestyle='dotted')
plt.xlabel('AVERAGE PULSE')
plt.ylabel('CALORIE BURNAGE',color='r')
plt.title('GRAPH',color='orange')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,color='purple',linestyle='dotted')
plt.xlabel('AVERAGE PULSE')
plt.ylabel('CALORIE BURNAGE',color='r')
plt.title('GRAPH',color='orange')
plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y,color='purple',linestyle='dotted')
plt.xlabel('AVERAGE')
plt.ylabel('MEANS',color='red')
plt.suptitle("ANKIT'S SINGH",color='orange')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('AVERAGE')
x=np.array([10,20,30,40])
y=np.array([2,4,6,8])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title('SALES')
plt.suptitle('GRAPHS')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y,color='y')
x=np.array([1,2,3,4,5])
y=np.array([10,20,30,40,50])
plt.subplot(1,2,2)
plt.scatter(x,y)
plt.suptitle("DATA")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,2,3,4,5])
y=([10,20,25,30,35])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,3,4,7,8])
y=np.array([14,20,24,35,40])
plt.scatter(x,y)
x=np.array([10,15,20,25,30])
y=np.array([11,14,20,34,25])
plt.scatter(x,y,color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,15,18,20,22])
y=np.array([10,20,30,40,50])
colors=np.array([0,5,10,20,30,40,50,60,70,70,80,90,100])
plt.scatter(x,y)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,20,30,40,50])
y=np.array([2,4,6,8,10])
plt.bar(x,y,width=5, color='r')
plt.title('DATA', color='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,14,17,20,25])
y=np.array([10,20,30,40,50])
plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([10,20,30,40,50])
y=(["A","B","C","D","E"])
plt.pie(x,labels=y)
plt.legend()
plt.show()
